# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 1 ⚡ Simple plot with 4 points


plt.plot([1,7,4,10,2]) #normal Vector
plt.show()

# %%
# 2 ⚡ Points have X & Y values. Title and axis labels, too.

plt.plot(["A","B","C"],["W","X","Y"])
#plt.title("Cesar's first try")
plt.title("Cesar's first try", fontsize=18, color='r')
plt.xlabel('x axis')
plt.ylabel('Up up')
plt.show()

# %%
# 3 ⚡ Change figure size
